# %%
# ===================== FUNCTION DEFINITIONS =====================

def CalMean(a, b):
    """
    This function calculates the harmonic mean of two numbers using the formula:
    Harmonic Mean = (a * b) / (a + b)
    
    Parameters:
        a (float or int): First number
        b (float or int): Second number
    
    Returns:
        None (Prints the calculated mean)
    """
    # Edge Case: Avoiding division by zero
    if a + b == 0:
        print(f"Cannot compute mean for {a} and {b}, as their sum is zero.")
        return
    
    mean = (a * b) / (a + b)  # Harmonic mean formula
    print(f"Mean of {a} and {b} =", mean)  # Displaying the result


def isGreater(a, b):
    """
    This function compares two numbers and prints whether the first number
    is greater than the second or not.

    Parameters:
        a (float or int): First number
        b (float or int): Second number
    
    Returns:
        None (Prints a message)
    """
    if a > b:
        print(f"{a} is greater than {b}")
    else:
        print(f"{b} is greater than or equal to {a}")


def isLesser(a, b):
    """
    This function is intended to check if a number is lesser than another.
    However, it is currently not implemented (uses 'pass').

    Parameters:
        a (float or int): First number
        b (float or int): Second number
    """
    pass  # Placeholder for future implementation


# ===================== FUNCTION CALLS & EXECUTION =====================

# Example 1: Comparing and computing mean for a = 10, b = 20
a, b = 10, 20  # Assign values to a and b
isGreater(a, b)  # Check which number is greater
CalMean(a, b)  # Compute mean of a and b

print("\n")  # Newline for better readability

# Example 2: Comparing and computing mean for c = 20, d = 30
c, d = 20, 30  # Assign new values
isGreater(c, d)  # Check which number is greater
CalMean(c, d)  # Compute mean of c and d

print("\n")  # Newline for better readability

# Example 3: Edge Case - Testing with zero sum
x, y = -10, 10  # Their sum is zero
CalMean(x, y)  # Should handle division by zero

print("\n")  # Newline for better readability

# Example 4: Edge Case - Testing with equal numbers
p, q = 50, 50
isGreater(p, q)  # Since numbers are equal, the function should handle it
CalMean(p, q)  # Compute mean of two equal numbers
# Out:
# 20 is greater than or equal to 10
# Mean of 10 and 20 = 6.666666666666667
#
#
# 30 is greater than or equal to 20
# Mean of 20 and 30 = 12.0
#
#
# Cannot compute mean for -10 and 10, as their sum is zero.
#
#
# 50 is greater than or equal to 50
# Mean of 50 and 50 = 25.0
